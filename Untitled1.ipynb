# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from data_prepare import *
import matplotlib.pyplot as plt
from params_select import *
import hyperopt.pyll.stochastic
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials, partial, rand, space_eval

# %%
# market = pd.read_csv("~/cs_market.csv", parse_dates=["date"], dtype={"code": str})
market = pd.read_csv("E:\market_data/cs_market.csv", parse_dates=["date"], dtype={"code": str})
all_ohlcv = market.drop(["Unnamed: 0", "total_turnover", "limit_up", "limit_down"], axis=1)
all_ohlcv = all_ohlcv.set_index('date')
ohlcv = all_ohlcv[all_ohlcv["code"] == "000725.XSHE"].drop("code", axis=1)

features = construct_features(ohlcv, construct_features1)

features_categorical = to_categorical(features.copy(), 'label', categorical_func_factory)

space = default_space
objective_func = construct_objective(features_categorical)
trials = Trials()
best = fmin(objective_func, space, algo=tpe.suggest, max_evals=40, trials=trials)
print(best)
# Out:
# {'batch_size': 2, 'dropout': 0.5, 'epochs': 1500, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': True, 'is_BN_2': False, 'is_BN_3': True, 'lr': 0.00016116472641595863, 'recurrent_dropout': 0.5, 'time_steps': 32, 'units1': 16, 'units2': 64, 'units3': 64}
# 10/10 [==============================] - 0s 3ms/step
# {'batch_size': 4, 'dropout': 0.2, 'epochs': 1500, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': True, 'is_BN_2': True, 'is_BN_3': True, 'lr': 0.0004410944559307307, 'recurrent_dropout': 0.4, 'time_steps': 32, 'units1': 16, 'units2': 32, 'units3': 16}
# 8/8 [==============================] - 0s 2ms/step
# {'batch_size': 2, 'dropout': 0.2, 'epochs': 1500, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': False, 'is_BN_2': False, 'is_BN_3': False, 'lr': 0.00034241653982038377, 'recurrent_dropout': 0.3, 'time_steps': 16, 'units1': 8, 'units2': 32, 'units3': 64}
# 22/22 [==============================] - 0s 2ms/step
# {'batch_size': 8, 'dropout': 0.5, 'epochs': 200, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': False, 'is_BN_2': True, 'is_BN_3': True, 'lr': 0.0009963511484660159, 'recurrent_dropout': 0.5, 'time_steps': 16, 'units1': 32, 'units2': 16, 'units3': 16}
# 16/16 [==============================] - 0s 623us/step
# {'batch_size': 8, 'dropout': 0.4, 'epochs': 500, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': True, 'is_BN_2': False, 'is_BN_3': True, 'lr': 0.00029289061213654964, 'recurrent_dropout': 0.2, 'time_steps': 32, 'units1': 64, 'units2': 8, 'units3': 8}
# 8/8 [==============================] - 0s 997us/step
# {'batch_size': 8, 'dropout': 0.1, 'epochs': 1000, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': True, 'is_BN_2': False, 'is_BN_3': False, 'lr': 0.0007155282022807186, 'recurrent_dropout': 0.4, 'time_steps': 8, 'units1': 16, 'units2': 64, 'units3': 64}
# 40/40 [==============================] - 0s 399us/step
# {'batch_size': 4, 'dropout': 0.5, 'epochs': 1500, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': True, 'is_BN_2': False, 'is_BN_3': True, 'lr': 0.0007099474388994915, 'recurrent_dropout': 0.4, 'time_steps': 8, 'units1': 8, 'units2': 8, 'units3': 16}
# 44/44 [==============================] - 0s 728us/step
# {'batch_size': 2, 'dropout': 0.4, 'epochs': 200, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': False, 'is_BN_2': False, 'is_BN_3': False, 'lr': 0.0008776388262426362, 'recurrent_dropout': 0.3, 'time_steps': 8, 'units1': 16, 'units2': 8, 'units3': 16}
# 46/46 [==============================] - 0s 1ms/step
# {'batch_size': 4, 'dropout': 0, 'epochs': 2000, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': True, 'is_BN_2': True, 'is_BN_3': True, 'lr': 0.0002029798859820685, 'recurrent_dropout': 0.1, 'time_steps': 8, 'units1': 64, 'units2': 16, 'units3': 16}
# 44/44 [==============================] - 0s 614us/step
# {'batch_size': 8, 'dropout': 0.2, 'epochs': 500, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': True, 'is_BN_2': False, 'is_BN_3': True, 'lr': 0.00010619490536787279, 'recurrent_dropout': 0.4, 'time_steps': 8, 'units1': 8, 'units2': 64, 'units3': 8}
# 40/40 [==============================] - 0s 374us/step
# {'batch_size': 2, 'dropout': 0.3, 'epochs': 1000, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': False, 'is_BN_2': False, 'is_BN_3': True, 'lr': 0.0006692886916035435, 'recurrent_dropout': 0, 'time_steps': 16, 'units1': 8, 'units2': 16, 'units3': 8}
# 22/22 [==============================] - 0s 2ms/step
# {'batch_size': 4, 'dropout': 0.4, 'epochs': 1000, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': True, 'is_BN_2': True, 'is_BN_3': False, 'lr': 0.0008240724268406135, 'recurrent_dropout': 0, 'time_steps': 16, 'units1': 64, 'units2': 64, 'units3': 32}
# 20/20 [==============================] - 0s 1ms/step
# {'batch_size': 2, 'dropout': 0.3, 'epochs': 1000, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': True, 'is_BN_2': True, 'is_BN_3': True, 'lr': 0.0009498988113810092, 'recurrent_dropout': 0.4, 'time_steps': 8, 'units1': 8, 'units2': 64, 'units3': 16}
# 46/46 [==============================] - 0s 1ms/step
# {'batch_size': 8, 'dropout': 0.4, 'epochs': 1000, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': True, 'is_BN_2': False, 'is_BN_3': True, 'lr': 0.0008553812768705378, 'recurrent_dropout': 0.3, 'time_steps': 16, 'units1': 16, 'units2': 8, 'units3': 64}
# 16/16 [==============================] - 0s 720us/step
# {'batch_size': 8, 'dropout': 0.5, 'epochs': 2000, 'initializer': <keras.initializers.VarianceScaling object at 0x00000160C2755748>, 'is_BN_1': True, 'is_BN_2': False, 'is_BN_3': False, 'lr': 0.0008722633770598643, 'recurrent_dropout': 0, 'time_steps': 8, 'units1': 32, 'units2': 16, 'units3': 8}
